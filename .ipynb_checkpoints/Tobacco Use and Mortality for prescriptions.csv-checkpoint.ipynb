# %% [markdown]
# ### *Importing Libraries and loading Data*

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
prescriptions_df = pd.read_csv("./prescriptions.csv")

# %%
prescriptions_df
# Out:
#        Year  All Pharmacotherapy Prescriptions  \
# 0   2014/15                               1348
# 1   2013/14                               1778
# 2   2012/13                               2203
# 3   2011/12                               2532
# 4   2010/11                               2564
# 5   2009/10                               2483
# 6   2008/09                               2263
# 7   2007/08                               2475
# 8   2006/07                               2079
# 9   2005/06                               2205
# 10  2004/05                               2044
#
#     Nicotine Replacement Therapy (NRT) Prescriptions  \
# 0                                                766
# 1                                               1059
# 2                                               1318
# 3                                               1545
# 4                                               1541
# 5                                               1559
# 6                                               1492
# 7                                               1756
# 8                                               1938
# 9                                               2076
# 10                                              1908
#
#     Bupropion (Zyban) Prescriptions  Varenicline (Champix) Prescriptions  \
# 0                                21                                561.0
# 1                                22                                697.0
# 2                                26                                859.0
# 3                                30                                957.0
# 4                                36                                987.0
# 5                                47                                877.0
# 6                                58                                714.0
# 7                               107                                612.0
# 8                               119                                 22.0
# 9                               129                                  NaN
# 10                              136                                  NaN
#
#     Net Ingredient Cost of All Pharmacotherapies  \
# 0                                          38145
# 1                                          48767
# 2                                          58121
# 3                                          64552
# 4                                          65883
# 5                                          63425
# 6                                          57520
# 7                                          61479
# 8                                          44817
# 9                                          48092
# 10                                         46093
#
#     Net Ingredient Cost of Nicotine Replacement Therapies (NRT)  \
# 0                                               18208
# 1                                               24257
# 2                                               28069
# 3                                               30951
# 4                                               30808
# 5                                               31429
# 6                                               30683
# 7                                               35883
# 8                                               39743
# 9                                               43465
# 10                                              40942
#
#     Net Ingredient Cost of Bupropion (Zyban)  \
# 0                                        807
# 1                                        865
# 2                                        994
# 3                                       1216
# 4                                       1581
# 5                                       2060
# 6                                       2143
# 7                                       3882
# 8                                       4315
# 9                                       4627
# 10                                      5151
#
#     Net Ingredient Cost of Varenicline (Champix)
# 0                                        19129.0
# 1                                        23646.0
# 2                                        29058.0
# 3                                        32385.0
# 4                                        33494.0
# 5                                        29936.0
# 6                                        24694.0
# 7                                        21714.0
# 8                                          760.0
# 9                                            NaN
# 10                                           NaN

# %%
prescriptions_df.shape
# Out:
# (11, 9)

# %%
prescriptions_df.columns
# Out:
# Index(['Year', 'All Pharmacotherapy Prescriptions',
#        'Nicotine Replacement Therapy (NRT) Prescriptions',
#        'Bupropion (Zyban) Prescriptions',
#        'Varenicline (Champix) Prescriptions',
#        'Net Ingredient Cost of All Pharmacotherapies',
#        'Net Ingredient Cost of Nicotine Replacement Therapies (NRT)',
#        'Net Ingredient Cost of Bupropion (Zyban)',
#        'Net Ingredient Cost of Varenicline (Champix)'],
#       dtype='object')

# %%
# Information about Dataset
prescriptions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 9 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Year                                                         11 non-null     object
#  1   All Pharmacotherapy Prescriptions                            11 non-null     int64
#  2   Nicotine Replacement Therapy (NRT) Prescriptions             11 non-null     int64
#  3   Bupropion (Zyban) Prescriptions                              11 non-null     int64
#  4   Varenicline (Champix) Prescriptions                          9 non-null      float64
#  5   Net Ingredient Cost of All Pharmacotherapies                 11 non-null     int64
#  6   Net Ingredient Cost of Nicotine Replacement Therapies (NRT)  11 non-null     int64
#  7   Net Ingredient Cost of Bupropion (Zyban)                     11 non-null     int64
#  8   Net Ingredient Cost of Varenicline (Champix)                 9 non-null      float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 924.0+ bytes

# %% [markdown]
# ### *Exploratory of Data Analysis*

# %%
# Summary Statistics of Numerical Columns
prescriptions_df.describe()
# Out:
#        All Pharmacotherapy Prescriptions  \
# count                          11.000000
# mean                         2179.454545
# std                           366.163724
# min                          1348.000000
# 25%                          2061.500000
# 50%                          2205.000000
# 75%                          2479.000000
# max                          2564.000000
#
#        Nicotine Replacement Therapy (NRT) Prescriptions  \
# count                                         11.000000
# mean                                        1541.636364
# std                                          388.608099
# min                                          766.000000
# 25%                                         1405.000000
# 50%                                         1545.000000
# 75%                                         1832.000000
# max                                         2076.000000
#
#        Bupropion (Zyban) Prescriptions  Varenicline (Champix) Prescriptions  \
# count                        11.000000                             9.000000
# mean                         66.454545                           698.444444
# std                          46.409834                           294.100370
# min                          21.000000                            22.000000
# 25%                          28.000000                           612.000000
# 50%                          47.000000                           714.000000
# 75%                         113.000000                           877.000000
# max                         136.000000                           987.000000
#
#        Net Ingredient Cost of All Pharmacotherapies  \
# count                                     11.000000
# mean                                   54263.090909
# std                                     9415.126292
# min                                    38145.000000
# 25%                                    47092.500000
# 50%                                    57520.000000
# 75%                                    62452.000000
# max                                    65883.000000
#
#        Net Ingredient Cost of Nicotine Replacement Therapies (NRT)  \
# count                                          11.000000
# mean                                        32221.636364
# std                                          7457.243771
# min                                         18208.000000
# 25%                                         29376.000000
# 50%                                         30951.000000
# 75%                                         37813.000000
# max                                         43465.000000
#
#        Net Ingredient Cost of Bupropion (Zyban)  \
# count                                 11.000000
# mean                                2512.818182
# std                                 1654.570870
# min                                  807.000000
# 25%                                 1105.000000
# 50%                                 2060.000000
# 75%                                 4098.500000
# max                                 5151.000000
#
#        Net Ingredient Cost of Varenicline (Champix)
# count                                      9.000000
# mean                                   23868.444444
# std                                     9942.113383
# min                                      760.000000
# 25%                                    21714.000000
# 50%                                    24694.000000
# 75%                                    29936.000000
# max                                    33494.000000

# %%
# Summary Statistics of categorical Columns
prescriptions_df.describe(include='object')
# Out:
#            Year
# count        11
# unique       11
# top     2014/15
# freq          1

# %% [markdown]
# ### *Handling Missing Value*

# %%
# Check missing value
prescriptions_df.isnull().sum()
# Out:
# Year                                                           0
# All Pharmacotherapy Prescriptions                              0
# Nicotine Replacement Therapy (NRT) Prescriptions               0
# Bupropion (Zyban) Prescriptions                                0
# Varenicline (Champix) Prescriptions                            2
# Net Ingredient Cost of All Pharmacotherapies                   0
# Net Ingredient Cost of Nicotine Replacement Therapies (NRT)    0
# Net Ingredient Cost of Bupropion (Zyban)                       0
# Net Ingredient Cost of Varenicline (Champix)                   2
# dtype: int64

# %%
prescriptions_df.isnull().mean()
# Out:
# Year                                                           0.000000
# All Pharmacotherapy Prescriptions                              0.000000
# Nicotine Replacement Therapy (NRT) Prescriptions               0.000000
# Bupropion (Zyban) Prescriptions                                0.000000
# Varenicline (Champix) Prescriptions                            0.181818
# Net Ingredient Cost of All Pharmacotherapies                   0.000000
# Net Ingredient Cost of Nicotine Replacement Therapies (NRT)    0.000000
# Net Ingredient Cost of Bupropion (Zyban)                       0.000000
# Net Ingredient Cost of Varenicline (Champix)                   0.181818
# dtype: float64

# %%
# Fill Null Value with 0
prescriptions_df['Net Ingredient Cost of Varenicline (Champix)'] = prescriptions_df['Net Ingredient Cost of Varenicline (Champix)'].fillna(0)

# %%
# Fill Null Value with 0
prescriptions_df['Varenicline (Champix) Prescriptions'] = prescriptions_df['Varenicline (Champix) Prescriptions'].fillna(0)

# %%
prescriptions_df
# Out:
#        Year  All Pharmacotherapy Prescriptions  \
# 0   2014/15                               1348
# 1   2013/14                               1778
# 2   2012/13                               2203
# 3   2011/12                               2532
# 4   2010/11                               2564
# 5   2009/10                               2483
# 6   2008/09                               2263
# 7   2007/08                               2475
# 8   2006/07                               2079
# 9   2005/06                               2205
# 10  2004/05                               2044
#
#     Nicotine Replacement Therapy (NRT) Prescriptions  \
# 0                                                766
# 1                                               1059
# 2                                               1318
# 3                                               1545
# 4                                               1541
# 5                                               1559
# 6                                               1492
# 7                                               1756
# 8                                               1938
# 9                                               2076
# 10                                              1908
#
#     Bupropion (Zyban) Prescriptions  Varenicline (Champix) Prescriptions  \
# 0                                21                                561.0
# 1                                22                                697.0
# 2                                26                                859.0
# 3                                30                                957.0
# 4                                36                                987.0
# 5                                47                                877.0
# 6                                58                                714.0
# 7                               107                                612.0
# 8                               119                                 22.0
# 9                               129                                  0.0
# 10                              136                                  0.0
#
#     Net Ingredient Cost of All Pharmacotherapies  \
# 0                                          38145
# 1                                          48767
# 2                                          58121
# 3                                          64552
# 4                                          65883
# 5                                          63425
# 6                                          57520
# 7                                          61479
# 8                                          44817
# 9                                          48092
# 10                                         46093
#
#     Net Ingredient Cost of Nicotine Replacement Therapies (NRT)  \
# 0                                               18208
# 1                                               24257
# 2                                               28069
# 3                                               30951
# 4                                               30808
# 5                                               31429
# 6                                               30683
# 7                                               35883
# 8                                               39743
# 9                                               43465
# 10                                              40942
#
#     Net Ingredient Cost of Bupropion (Zyban)  \
# 0                                        807
# 1                                        865
# 2                                        994
# 3                                       1216
# 4                                       1581
# 5                                       2060
# 6                                       2143
# 7                                       3882
# 8                                       4315
# 9                                       4627
# 10                                      5151
#
#     Net Ingredient Cost of Varenicline (Champix)
# 0                                        19129.0
# 1                                        23646.0
# 2                                        29058.0
# 3                                        32385.0
# 4                                        33494.0
# 5                                        29936.0
# 6                                        24694.0
# 7                                        21714.0
# 8                                          760.0
# 9                                            0.0
# 10                                           0.0

# %% [markdown]
# ### *Data Analysis and Visualizations*

# %%
Data = [prescriptions_df['Year'],prescriptions_df['All Pharmacotherapy Prescriptions'],prescriptions_df['Net Ingredient Cost of All Pharmacotherapies']]

# %%
Pharmacotherapy_df = pd.DataFrame(Data)

# %%
Pharmacotherapy_df
# Out:
#                                                    0        1        2   \
# Year                                          2014/15  2013/14  2012/13
# All Pharmacotherapy Prescriptions                1348     1778     2203
# Net Ingredient Cost of All Pharmacotherapies    38145    48767    58121
#
#                                                    3        4        5   \
# Year                                          2011/12  2010/11  2009/10
# All Pharmacotherapy Prescriptions                2532     2564     2483
# Net Ingredient Cost of All Pharmacotherapies    64552    65883    63425
#
#                                                    6        7        8   \
# Year                                          2008/09  2007/08  2006/07
# All Pharmacotherapy Prescriptions                2263     2475     2079
# Net Ingredient Cost of All Pharmacotherapies    57520    61479    44817
#
#                                                    9        10
# Year                                          2005/06  2004/05
# All Pharmacotherapy Prescriptions                2205     2044
# Net Ingredient Cost of All Pharmacotherapies    48092    46093

# %%
# How many All Pharmacotherapy Prescriptions in year
plt.figure(figsize=(15,10))
sns.barplot(x = prescriptions_df['Year'], y = prescriptions_df['All Pharmacotherapy Prescriptions'], palette='magma')
plt.title('All Pharmacotherapy Prescriptions in year')
plt.xlabel('Year')
plt.ylabel('All Pharmacotherapy Prescriptions')
plt.show()

# %%
Data = [prescriptions_df['Year'],prescriptions_df['Nicotine Replacement Therapy (NRT) Prescriptions'],prescriptions_df['Net Ingredient Cost of Nicotine Replacement Therapies (NRT)']]

# %%
Nicotine_df = pd.DataFrame(Data)

# %%
Nicotine_df
# Out:
#                                                          0        1        2   \
# Year                                                2014/15  2013/14  2012/13
# Nicotine Replacement Therapy (NRT) Prescriptions        766     1059     1318
# Net Ingredient Cost of Nicotine Replacement The...    18208    24257    28069
#
#                                                          3        4        5   \
# Year                                                2011/12  2010/11  2009/10
# Nicotine Replacement Therapy (NRT) Prescriptions       1545     1541     1559
# Net Ingredient Cost of Nicotine Replacement The...    30951    30808    31429
#
#                                                          6        7        8   \
# Year                                                2008/09  2007/08  2006/07
# Nicotine Replacement Therapy (NRT) Prescriptions       1492     1756     1938
# Net Ingredient Cost of Nicotine Replacement The...    30683    35883    39743
#
#                                                          9        10
# Year                                                2005/06  2004/05
# Nicotine Replacement Therapy (NRT) Prescriptions       2076     1908
# Net Ingredient Cost of Nicotine Replacement The...    43465    40942

# %%
# How many Nicotine Replacement Therapy (NRT) Prescriptions in year
plt.figure(figsize=(15,10))
sns.barplot(x = prescriptions_df['Year'], y = prescriptions_df['Nicotine Replacement Therapy (NRT) Prescriptions'], palette='magma')
plt.title('Nicotine Replacement Therapy (NRT) Prescriptions in year')
plt.xlabel('Year')
plt.ylabel('Nicotine Replacement Therapy (NRT) Prescriptions')
plt.show()

# %%
Data = [prescriptions_df['Year'],prescriptions_df['Bupropion (Zyban) Prescriptions'],prescriptions_df['Net Ingredient Cost of Bupropion (Zyban)']]

# %%
Bupropion_df = pd.DataFrame(Data)

# %%
Bupropion_df
# Out:
#                                                0        1        2        3   \
# Year                                      2014/15  2013/14  2012/13  2011/12
# Bupropion (Zyban) Prescriptions                21       22       26       30
# Net Ingredient Cost of Bupropion (Zyban)      807      865      994     1216
#
#                                                4        5        6        7   \
# Year                                      2010/11  2009/10  2008/09  2007/08
# Bupropion (Zyban) Prescriptions                36       47       58      107
# Net Ingredient Cost of Bupropion (Zyban)     1581     2060     2143     3882
#
#                                                8        9        10
# Year                                      2006/07  2005/06  2004/05
# Bupropion (Zyban) Prescriptions               119      129      136
# Net Ingredient Cost of Bupropion (Zyban)     4315     4627     5151

# %%
# How many Bupropion (Zyban) Prescriptions in year
plt.figure(figsize=(15,10))
sns.barplot(x = prescriptions_df['Year'], y = prescriptions_df['Bupropion (Zyban) Prescriptions'], palette='magma')
plt.title('Bupropion (Zyban) Prescriptions in year')
plt.xlabel('Year')
plt.ylabel('Bupropion (Zyban) Prescriptions')
plt.show()

# %%
Data = [prescriptions_df['Year'],prescriptions_df['Varenicline (Champix) Prescriptions'],prescriptions_df['Net Ingredient Cost of Varenicline (Champix)']]

# %%
Varenicline_df = pd.DataFrame(Data)

# %%
Varenicline_df
# Out:
#                                                    0        1        2   \
# Year                                          2014/15  2013/14  2012/13
# Varenicline (Champix) Prescriptions             561.0    697.0    859.0
# Net Ingredient Cost of Varenicline (Champix)  19129.0  23646.0  29058.0
#
#                                                    3        4        5   \
# Year                                          2011/12  2010/11  2009/10
# Varenicline (Champix) Prescriptions             957.0    987.0    877.0
# Net Ingredient Cost of Varenicline (Champix)  32385.0  33494.0  29936.0
#
#                                                    6        7        8   \
# Year                                          2008/09  2007/08  2006/07
# Varenicline (Champix) Prescriptions             714.0    612.0     22.0
# Net Ingredient Cost of Varenicline (Champix)  24694.0  21714.0    760.0
#
#                                                    9        10
# Year                                          2005/06  2004/05
# Varenicline (Champix) Prescriptions               NaN      NaN
# Net Ingredient Cost of Varenicline (Champix)      NaN      NaN

# %%
# How many Varenicline (Champix) Prescriptions in year
plt.figure(figsize=(15,10))
sns.barplot(x = prescriptions_df['Year'], y = prescriptions_df['Varenicline (Champix) Prescriptions'], palette='magma')
plt.title('Varenicline (Champix) Prescriptions in year')
plt.xlabel('Year')
plt.ylabel('Varenicline (Champix) Prescriptions')
plt.show()

# %%
prescriptions_df = pd.read_csv("./prescriptions.csv")

# %%
(prescriptions_df['Year'][0])[:4]
# Out:
# '2014'

# %%
for i in range(0, len(prescriptions_df['Year'])):
    res = (prescriptions_df['Year'][0])[:4]
    print(res)
# Out:
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014

# %%
prescriptions_df['Year']
# Out:
# 0     2014/15
# 1     2014/15
# 2     2014/15
# 3     2014/15
# 4     2014/15
# 5     2014/15
# 6     2014/15
# 7     2014/15
# 8     2014/15
# 9     2014/15
# 10    2014/15
# Name: Year, dtype: object

# %%
#import datetime
#prescriptions_df["Year"] = prescriptions_df["Year"].apply(lambda x: datetime.datetime.strptime(x, '%Y/%d').year())

#prescriptions_df['Year'] = pd.set_option('prescriptions_df['Year'].date_format', lambda x: ',%y', %x)

# %%
#prescriptions_df['Year'] = prescriptions_df['Year'].dt.strftime('%Y/%d/%m')
#prescriptions_df['Year'] = pd.to_datetime(prescriptions_df['Year'], '%Y-%d-%m', errors='coerce')
#prescriptions_df['Year'] = prescriptions_df['Year'].dt.to_period('y')
#prescriptions_df.Year.index = prescriptions_df.Year.index.strftime('%Y-%m')

# %%
prescriptions_df['Year']
# Out:
# 0      NaT
# 1      NaT
# 2      NaT
# 3     2011
# 4     2010
# 5     2009
# 6     2008
# 7     2007
# 8     2006
# 9     2005
# 10    2004
# Name: Year, dtype: period[Y-DEC]

# %%
# Check Correlation between them
plt.figure(figsize=(15,10))
sns.heatmap(Pharmacotherapy_df.corr(), annot=True)
plt.show()

# %%
# Convert Date columns to datetime
#prescriptions_df['year'] = pd.DatetimeIndex(prescriptions_df['Year']).year
#prescriptions_df['Year'] = prescriptions_df['Year'].dt.year
#prescriptions_df['Year'] = pd.to_datetime(prescriptions_df['Year'], errors='coerce')
#prescriptions_df['Year'] = prescriptions_df['Year'].dt.to_period('y')
#prescriptions_df['Year'] = prescriptions_df['Year'].dt.strftime('%Y')
